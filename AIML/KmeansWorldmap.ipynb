# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %%
sns.set()
raw_data = pd.read_csv("Countries-exercise.csv")
data = raw_data.copy()
plt.scatter(data['Longitude'], data['Latitude'])
plt.xlim(-180,180)
plt.ylim(-90, 90)
plt.show()

# %%
x = data.iloc[:,1:3]
kmeans = KMeans(12)
kmeans.fit(x)
identified_clusters = kmeans.fit_predict(x)
data_with_clusters = data.copy()
data_with_clusters['Cluster'] = identified_clusters
plt.scatter(data['Longitude'], data['Latitude'], c=data_with_clusters['Cluster'], cmap='Accent')
plt.xlim(-180,180)
plt.ylim(-90, 90)
plt.show()

# %%
dataf=pd.DataFrame(identified_clusters)
print(dataf.head())
# Out:
#    0
# 0  0
# 1  1
# 2  5
# 3  0
# 4  2
